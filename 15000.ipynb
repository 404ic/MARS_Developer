# %% [markdown]
# # Full MARS demo
#
# This is the tutorial from the readme of MARS_Developer in Jupyter notebook form.

# %% [markdown]
# ## 1. 📁 Create a new MARS Training Project

# %%
from create_new_project import *

location = '/home/cristina/Desktop/ericykma/annotation_budget_projects'
name = '15000_frames_1_annotator'

create_new_project(location, name,
                   download_MARS_checkpoints=False,
                   download_demo_data=False)
# Out:
# Project 15000_frames_1_annotator created successfully.

# %% [markdown]
# Within your project folder is a file called `project_config.yaml`. This file contains many important features: keypoint and animal names, instructions for your annotation job, and names/data assignments for detection and pose models. Open this file in a text editor and fill in the fields as instructed in the comments.

# %% [markdown]
# # 2 Post-process the manual pose annotations
# This script carries out several steps to create "ground truth" keypoint locations by taking the median across AWS workers, correct for left/right flips of body part labels, and package your data for model-training. The processed annotation data will be added as a new file to `annotation_data`.

# %%
import pose_annotation_tools.annotation_postprocessing
import importlib
importlib.reload(pose_annotation_tools.annotation_postprocessing)
from pose_annotation_tools.annotation_postprocessing import *

project_path = '/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator'
annotation_postprocessing(project_path)
# Out:
# WARNING:tensorflow:From /home/cristina/anaconda3/envs/mars_dev/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Processing manifest file...
#   frame 1000
#   frame 2000
#   frame 3000
#   frame 4000
#   frame 5000
#   frame 6000
#   frame 7000
#   frame 8000
#   frame 9000
#   frame 10000
#   frame 11000
#   frame 12000
#   frame 13000
#   frame 14000
# Ground-truth keypoint locations extracted!
# DID NOT SHUFFLE
# Generating black_top detection training files...
# done.
# Generating top pose training files...
# done.
# Generating black_top priors...
# done.

# %% [markdown]
# ### 2.4 Visualize some manual pose annotations
#
# We'll next take a look at the inter-annotator variability in your pose labels, as this is a good predictor for how well MARS will perform. (If you annotated pose yourself you can skip this step.)
#
# To look at annotations on an example frame, call `plot_frame`. It takes as input a project path and a number (specifying the image in your annotation dataset.) It also takes two optional plotting arguments:
# * `markersize` the size of the keypoint makers (default is 8)
# * `figsize` the width and height of the plot (default is [15,20])
#
# The colored points are the raw annotation data. Points are colored by body part, and all points of a given marker shape come from the same worker. The black and white points are the medians across annotators. These medians are the "ground truth" that we'll use to train MARS.

# %%
from pose_annotation_tools.evaluation import *

project_path = '/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator'
frame_num = 42  # the frame number to look at in your data

plot_frame(project_path,frame_num, markersize=5, figsize=[10,10])

# %% [markdown]
# To summarize worker performance, we'll look at the **Percent Correct Keypoints (PCK)**. This is the percentage of keypoints from individual workers that fall within a radius X of the "ground truth" worker median.
#
# For each keypoint, we compute the distance from each worker's annotation to the median of the remaining workers, on each frame. We then plot cdfs of **median** (dashed line) worker-to-median distances for each frame, as well as a shaded area whose upper and lower bounds are the min and max worker-to-median distances, respectively.
#
# The "all" plot takes the framewise average across keypoints, for each metric.
#
# `plot_human_PCK` summarizes worker performance for your dataset. It takes four optional arguments:
# * `animal_names` specifies which animals to generates plots for (defaults to all.)
# * `xlim` is a two-element list specifying the min and max bounds of the x axis for all subplots.
# * `pixel_units=True` plots in units of pixels instead of cm.
# * `combine_animals=True` pools data across animal types in your dataset.

# %%
from pose_annotation_tools.evaluation import *

project_path = '/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator'
plot_human_PCK(project_path, combine_animals=False)

# %% [markdown]
# ## 3. 🎯 Fine-tune the MARS detector to your data
#
#
# ### 3.1 Run the training code
# `run_training` takes two optional arguments:
# * `models` takes names of detectors to train, in case you only want to work on one detector at a time (MARS trains all detectors sequentially by default.)
# * `max_training_steps` overrides `NUM_TRAIN_ITERATIONS` in `train_config.yaml` (300,000 by default). You can set this to a small number to confirm everything is working before launching your full training job.
#
# If training is interrupted, it will resume from the most recent model checkpoint; MARS saves checkpoints every 30 minutes (adjust this in `my_project/detection/train_config.yaml`), and when training completes.

# %%
from multibox_detection import train_detect
import importlib
importlib.reload(train_detect)

project_path = '/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator'
train_detect.run_training(project_path, max_training_steps=100000)

# %%
import new_eval as eval
import importlib
importlib.reload(eval)
project_path = '/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator/'
eval.run_evaluation(project_path)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# /home/cristina/Desktop/ericykma/m_dev_fork/MARS_Developer/new_eval.py:289: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   bbox_priors = np.array(bbox_priors).astype(np.float32)
# INFO:tensorflow:Restoring parameters from /home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator/detection/black_top_log/model.ckpt-100000
# Found model for global step: 100000
# Step: 1, Time/image (ms): 643.2
# Step: 2, Time/image (ms): 13.2
# Step: 3, Time/image (ms): 13.0
# Step: 4, Time/image (ms): 12.8
# Step: 5, Time/image (ms): 13.0
# Step: 6, Time/image (ms): 12.8
# Step: 7, Time/image (ms): 12.9
# Step: 8, Time/image (ms): 12.8
# Step: 9, Time/image (ms): 12.8
# Step: 10, Time/image (ms): 12.8
# Step: 11, Time/image (ms): 12.9
# Step: 12, Time/image (ms): 12.8
# Step: 13, Time/image (ms): 12.8
# Step: 14, Time/image (ms): 12.8
# Step: 15, Time/image (ms): 12.8
# Step: 16, Time/image (ms): 12.8
# Step: 17, Time/image (ms): 12.9
# Step: 18, Time/image (ms): 12.8
# Step: 19, Time/image (ms): 12.9
# Step: 20, Time/image (ms): 12.8
# Step: 21, Time/image (ms): 13.0
# Step: 22, Time/image (ms): 12.8
# Step: 23, Time/image (ms): 12.9
# Step: 24, Time/image (ms): 12.8
# Step: 25, Time/image (ms): 12.8
# Step: 26, Time/image (ms): 12.8
# Step: 27, Time/image (ms): 12.8
# Step: 28, Time/image (ms): 12.8
# Step: 29, Time/image (ms): 12.8
# Step: 30, Time/image (ms): 12.8
# Step: 31, Time/image (ms): 12.7
# Step: 32, Time/image (ms): 12.8
# Step: 33, Time/image (ms): 12.8
# Step: 34, Time/image (ms): 12.8
# Step: 35, Time/image (ms): 12.8
# Step: 36, Time/image (ms): 12.8
# Step: 37, Time/image (ms): 12.8
# Step: 38, Time/image (ms): 12.8
# Step: 39, Time/image (ms): 12.8
# Step: 40, Time/image (ms): 12.8
# Step: 41, Time/image (ms): 12.8
# Step: 42, Time/image (ms): 12.8
# Step: 43, Time/image (ms): 12.8
# Step: 44, Time/image (ms): 12.8
# Step: 45, Time/image (ms): 12.9
# Step: 46, Time/image (ms): 12.8
# Step: 47, Time/image (ms): 12.9
# Step: 48, Time/image (ms): 12.9
# Step: 49, Time/image (ms): 12.9
# Step: 50, Time/image (ms): 12.8
# Step: 51, Time/image (ms): 12.9
# Step: 52, Time/image (ms): 12.8
# Step: 53, Time/image (ms): 12.7
# Step: 54, Time/image (ms): 12.8
# Step: 55, Time/image (ms): 12.8
# Step: 56, Time/image (ms): 12.8
# Step: 57, Time/image (ms): 12.8
# Step: 58, Time/image (ms): 12.8
# Step: 59, Time/image (ms): 12.8
# Step: 60, Time/image (ms): 12.8
# Step: 61, Time/image (ms): 12.8
# Step: 62, Time/image (ms): 12.8
# Step: 63, Time/image (ms): 12.8
# Step: 64, Time/image (ms): 12.8
# Step: 65, Time/image (ms): 12.8
# Step: 66, Time/image (ms): 12.8
# Step: 67, Time/image (ms): 12.8
# Step: 68, Time/image (ms): 12.8
# Step: 69, Time/image (ms): 12.8
# Step: 70, Time/image (ms): 12.8
# Step: 71, Time/image (ms): 12.8
# Step: 72, Time/image (ms): 12.8
# Step: 73, Time/image (ms): 13.0
# Step: 74, Time/image (ms): 12.8
# Step: 75, Time/image (ms): 12.8
# Step: 76, Time/image (ms): 12.9
# Step: 77, Time/image (ms): 12.8
# Step: 78, Time/image (ms): 12.9
# Step: 79, Time/image (ms): 12.8
# Step: 80, Time/image (ms): 12.9
# Step: 81, Time/image (ms): 12.8
# Step: 82, Time/image (ms): 12.8
# Step: 83, Time/image (ms): 12.8
# Step: 84, Time/image (ms): 12.8
# Step: 85, Time/image (ms): 12.8
# Step: 86, Time/image (ms): 12.8
# Step: 87, Time/image (ms): 12.8
# Step: 88, Time/image (ms): 12.8
# Step: 89, Time/image (ms): 12.8
# Step: 90, Time/image (ms): 12.9
# Step: 91, Time/image (ms): 12.8
# Step: 92, Time/image (ms): 12.8
# Step: 93, Time/image (ms): 12.8
# Step: 94, Time/image (ms): 12.8
# Step: 95, Time/image (ms): 12.8
# Step: 96, Time/image (ms): 12.8
# Step: 97, Time/image (ms): 12.8
# Step: 98, Time/image (ms): 12.8
# Step: 99, Time/image (ms): 12.9
# Step: 100, Time/image (ms): 12.8
# Step: 101, Time/image (ms): 12.8
# Step: 102, Time/image (ms): 12.9
# Step: 103, Time/image (ms): 12.9
# Step: 104, Time/image (ms): 12.8
# Step: 105, Time/image (ms): 12.9
# Step: 106, Time/image (ms): 12.8
# Step: 107, Time/image (ms): 12.8
# Step: 108, Time/image (ms): 12.8
# Step: 109, Time/image (ms): 12.8
# Step: 110, Time/image (ms): 12.8
# Step: 111, Time/image (ms): 12.8
# Step: 112, Time/image (ms): 12.9
# Step: 113, Time/image (ms): 12.8
# Step: 114, Time/image (ms): 12.8
# Step: 115, Time/image (ms): 12.8
# Step: 116, Time/image (ms): 12.8
# Step: 117, Time/image (ms): 12.8
# Step: 118, Time/image (ms): 12.8
# Step: 119, Time/image (ms): 12.8
# Step: 120, Time/image (ms): 12.7
# Step: 121, Time/image (ms): 12.8
# Step: 122, Time/image (ms): 12.8
# Step: 123, Time/image (ms): 12.9
# Step: 124, Time/image (ms): 12.8
# Step: 125, Time/image (ms): 12.9
# Step: 126, Time/image (ms): 12.9
# Step: 127, Time/image (ms): 12.9
# Step: 128, Time/image (ms): 12.9
# Step: 129, Time/image (ms): 12.8
# Step: 130, Time/image (ms): 12.8
# Step: 131, Time/image (ms): 12.8
# Step: 132, Time/image (ms): 12.8
# Step: 133, Time/image (ms): 12.8
# Step: 134, Time/image (ms): 12.8
# Step: 135, Time/image (ms): 12.8
# Step: 136, Time/image (ms): 12.8
# Step: 137, Time/image (ms): 12.9
# Step: 138, Time/image (ms): 12.8
# Step: 139, Time/image (ms): 12.8
# Step: 140, Time/image (ms): 12.8
# Step: 141, Time/image (ms): 12.9
# Step: 142, Time/image (ms): 12.9
# Step: 143, Time/image (ms): 12.8
# Step: 144, Time/image (ms): 12.8
# Step: 145, Time/image (ms): 12.8
# Step: 146, Time/image (ms): 12.9
# Step: 147, Time/image (ms): 12.7
# Step: 148, Time/image (ms): 12.7
# Step: 149, Time/image (ms): 12.8
# Step: 150, Time/image (ms): 13.0
# Step: 151, Time/image (ms): 12.8
# Step: 152, Time/image (ms): 12.8
# Step: 153, Time/image (ms): 12.8
# Step: 154, Time/image (ms): 12.8
# Step: 155, Time/image (ms): 12.7
# Step: 156, Time/image (ms): 12.8
# Step: 157, Time/image (ms): 12.8
# Step: 158, Time/image (ms): 12.9
# Step: 159, Time/image (ms): 12.8
# Step: 160, Time/image (ms): 12.8
# Step: 161, Time/image (ms): 12.8
# Step: 162, Time/image (ms): 12.8
# Step: 163, Time/image (ms): 12.8
# Step: 164, Time/image (ms): 12.8
# Step: 165, Time/image (ms): 12.8
# Step: 166, Time/image (ms): 12.8
# Step: 167, Time/image (ms): 12.8
# Step: 168, Time/image (ms): 12.8
# Step: 169, Time/image (ms): 12.8
# Step: 170, Time/image (ms): 12.8
# Step: 171, Time/image (ms): 12.8
# Step: 172, Time/image (ms): 12.8
# Step: 173, Time/image (ms): 12.8
# Step: 174, Time/image (ms): 12.8
# Step: 175, Time/image (ms): 12.8
# Step: 176, Time/image (ms): 12.8
# Step: 177, Time/image (ms): 12.8
# Step: 178, Time/image (ms): 12.8
# Step: 179, Time/image (ms): 12.7
# Step: 180, Time/image (ms): 12.8
# Step: 181, Time/image (ms): 12.8
# Step: 182, Time/image (ms): 12.9
# Step: 183, Time/image (ms): 12.8
# Step: 184, Time/image (ms): 12.8
# Step: 185, Time/image (ms): 12.8
# Step: 186, Time/image (ms): 12.8
# Step: 187, Time/image (ms): 12.7
# Step: 188, Time/image (ms): 14.7
# Step: 189, Time/image (ms): 12.9
# Step: 190, Time/image (ms): 12.8
# Step: 191, Time/image (ms): 12.8
# Step: 192, Time/image (ms): 12.8
# Step: 193, Time/image (ms): 12.8
# Step: 194, Time/image (ms): 12.8
# Step: 195, Time/image (ms): 12.8
# Step: 196, Time/image (ms): 12.7
# Step: 197, Time/image (ms): 12.8
# Step: 198, Time/image (ms): 12.8
# Step: 199, Time/image (ms): 12.8
# Step: 200, Time/image (ms): 12.9
# Step: 201, Time/image (ms): 12.8
# Step: 202, Time/image (ms): 12.8
# Step: 203, Time/image (ms): 12.8
# Step: 204, Time/image (ms): 12.8
# Step: 205, Time/image (ms): 13.2
# Step: 206, Time/image (ms): 12.8
# Step: 207, Time/image (ms): 12.9
# Step: 208, Time/image (ms): 12.9
# Step: 209, Time/image (ms): 12.8
# Step: 210, Time/image (ms): 12.8
# Step: 211, Time/image (ms): 12.8
# Step: 212, Time/image (ms): 12.8
# Step: 213, Time/image (ms): 12.8
# Step: 214, Time/image (ms): 12.8
# Step: 215, Time/image (ms): 12.8
# Step: 216, Time/image (ms): 12.8
# Step: 217, Time/image (ms): 12.8
# Step: 218, Time/image (ms): 12.8
# Step: 219, Time/image (ms): 12.8
# Step: 220, Time/image (ms): 12.8
# Step: 221, Time/image (ms): 12.8
# Step: 222, Time/image (ms): 12.8
# Step: 223, Time/image (ms): 12.8
# Step: 224, Time/image (ms): 12.8
# Step: 225, Time/image (ms): 12.8
# Step: 226, Time/image (ms): 12.8
# Step: 227, Time/image (ms): 12.8
# Step: 228, Time/image (ms): 12.8
# Step: 229, Time/image (ms): 12.8
# Step: 230, Time/image (ms): 12.8
# Step: 231, Time/image (ms): 12.8
# Step: 232, Time/image (ms): 12.8
# Step: 233, Time/image (ms): 12.8
# Step: 234, Time/image (ms): 12.8
# Step: 235, Time/image (ms): 12.8
# Step: 236, Time/image (ms): 12.8
# Step: 237, Time/image (ms): 12.8
# Step: 238, Time/image (ms): 12.8
# Step: 239, Time/image (ms): 12.8
# Step: 240, Time/image (ms): 12.8
# Step: 241, Time/image (ms): 12.8
# Step: 242, Time/image (ms): 12.8
# Step: 243, Time/image (ms): 12.8
# Step: 244, Time/image (ms): 12.8
# Step: 245, Time/image (ms): 12.8
# Step: 246, Time/image (ms): 12.8
# Step: 247, Time/image (ms): 12.8
# Step: 248, Time/image (ms): 12.9
# Step: 249, Time/image (ms): 12.9
# Step: 250, Time/image (ms): 12.8
# Step: 251, Time/image (ms): 12.8
# Step: 252, Time/image (ms): 12.7
# Step: 253, Time/image (ms): 12.8
# Step: 254, Time/image (ms): 12.8
# Step: 255, Time/image (ms): 12.8
# Step: 256, Time/image (ms): 12.8
# Step: 257, Time/image (ms): 12.8
# Step: 258, Time/image (ms): 12.8
# Step: 259, Time/image (ms): 12.8
# Step: 260, Time/image (ms): 12.8
# Step: 261, Time/image (ms): 12.8
# Step: 262, Time/image (ms): 12.8
# Step: 263, Time/image (ms): 12.8
# Step: 264, Time/image (ms): 12.8
# Step: 265, Time/image (ms): 12.8
# Step: 266, Time/image (ms): 12.8
# Step: 267, Time/image (ms): 12.9
# Step: 268, Time/image (ms): 12.8
# Step: 269, Time/image (ms): 12.8
# Step: 270, Time/image (ms): 12.8
# Step: 271, Time/image (ms): 12.8
# Step: 272, Time/image (ms): 12.8
# Step: 273, Time/image (ms): 12.8
# Step: 274, Time/image (ms): 12.8
# Step: 275, Time/image (ms): 12.8
# Step: 276, Time/image (ms): 12.8
# Step: 277, Time/image (ms): 12.8
# Step: 278, Time/image (ms): 12.8
# Step: 279, Time/image (ms): 12.8
# Step: 280, Time/image (ms): 12.8
# Step: 281, Time/image (ms): 12.8
# Step: 282, Time/image (ms): 12.8
# Step: 283, Time/image (ms): 12.9
# Step: 284, Time/image (ms): 12.9
# Step: 285, Time/image (ms): 12.9
# Step: 286, Time/image (ms): 12.9
# Step: 287, Time/image (ms): 12.9
# Step: 288, Time/image (ms): 12.9
# Step: 289, Time/image (ms): 12.8
# Step: 290, Time/image (ms): 12.8
# Step: 291, Time/image (ms): 12.8
# Step: 292, Time/image (ms): 12.8
# Step: 293, Time/image (ms): 12.8
# Step: 294, Time/image (ms): 12.8
# Step: 295, Time/image (ms): 12.8
# Step: 296, Time/image (ms): 12.9
# Step: 297, Time/image (ms): 12.8
# Step: 298, Time/image (ms): 12.8
# Step: 299, Time/image (ms): 12.8
# Step: 300, Time/image (ms): 12.8
# Step: 301, Time/image (ms): 12.8
# Step: 302, Time/image (ms): 12.8
# Step: 303, Time/image (ms): 12.8
# Step: 304, Time/image (ms): 12.8
# Step: 305, Time/image (ms): 12.9
# Step: 306, Time/image (ms): 12.8
# Step: 307, Time/image (ms): 12.9
# Step: 308, Time/image (ms): 12.8
# Step: 309, Time/image (ms): 12.8
# Step: 310, Time/image (ms): 12.8
# Step: 311, Time/image (ms): 12.8
# Step: 312, Time/image (ms): 12.8
# Step: 313, Time/image (ms): 12.8
# Step: 314, Time/image (ms): 12.8
# Step: 315, Time/image (ms): 12.7
# Step: 316, Time/image (ms): 12.8
# Step: 317, Time/image (ms): 12.8
# Step: 318, Time/image (ms): 12.8
# Step: 319, Time/image (ms): 12.8
# Step: 320, Time/image (ms): 12.8
# Step: 321, Time/image (ms): 12.8
# Step: 322, Time/image (ms): 12.8
# Step: 323, Time/image (ms): 12.8
# Step: 324, Time/image (ms): 12.8
# Step: 325, Time/image (ms): 12.8
# Step: 326, Time/image (ms): 12.8
# Step: 327, Time/image (ms): 12.8
# Step: 328, Time/image (ms): 12.7
# Step: 329, Time/image (ms): 12.8
# Step: 330, Time/image (ms): 12.8
# Step: 331, Time/image (ms): 12.9
# Step: 332, Time/image (ms): 12.8
# Step: 333, Time/image (ms): 12.9
# Step: 334, Time/image (ms): 12.8
# Step: 335, Time/image (ms): 12.8
# Step: 336, Time/image (ms): 12.7
# Step: 337, Time/image (ms): 12.7
# Step: 338, Time/image (ms): 12.8
# Step: 339, Time/image (ms): 12.8
# Step: 340, Time/image (ms): 12.8
# Step: 341, Time/image (ms): 12.9
# Step: 342, Time/image (ms): 12.8
# Step: 343, Time/image (ms): 12.7
# Step: 344, Time/image (ms): 12.8
# Step: 345, Time/image (ms): 12.9
# Step: 346, Time/image (ms): 13.0
# Step: 347, Time/image (ms): 12.9
# Step: 348, Time/image (ms): 12.8
# Step: 349, Time/image (ms): 13.0
# Step: 350, Time/image (ms): 12.9
# Step: 351, Time/image (ms): 12.8
# Step: 352, Time/image (ms): 12.8
# Step: 353, Time/image (ms): 12.8
# Step: 354, Time/image (ms): 12.8
# Step: 355, Time/image (ms): 12.7
# Step: 356, Time/image (ms): 12.7
# Step: 357, Time/image (ms): 12.8
# Step: 358, Time/image (ms): 12.8
# Step: 359, Time/image (ms): 12.8
# Step: 360, Time/image (ms): 12.8
# Step: 361, Time/image (ms): 12.8
# Step: 362, Time/image (ms): 12.9
# Step: 363, Time/image (ms): 12.9
# Step: 364, Time/image (ms): 13.0
# Step: 365, Time/image (ms): 12.9
# Step: 366, Time/image (ms): 13.0
# Step: 367, Time/image (ms): 12.9
# Step: 368, Time/image (ms): 12.9
# Step: 369, Time/image (ms): 12.9
# Step: 370, Time/image (ms): 12.8
# Step: 371, Time/image (ms): 12.8
# Step: 372, Time/image (ms): 12.8
# Step: 373, Time/image (ms): 12.9
# Step: 374, Time/image (ms): 12.8
# Step: 375, Time/image (ms): 12.8
# eval: pred_annotations.shape is (150000, 7)
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (150000, 7)
# 0/150000
# DONE (t=0.68s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=5.10s).
# Accumulating evaluation results...
# DONE (t=0.71s).
# Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ]: 0.543
# Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ]: 0.973
# Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ]: 0.539
# Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ]: -1.000
# Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ]: 0.000
# Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ]: 0.635
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ]: 0.627
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ]: 0.635
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ]: 0.642
# Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ]: -1.000
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ]: 0.050
# Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ]: 0.644

# %%
import multibox_detection.prcurve_separate
importlib.reload(multibox_detection.prcurve_separate)
from multibox_detection.prcurve_separate import *
prcurve(project_path)
# Out:
# loaded

# %%
from multibox_detection import evaluate_detection
import importlib
importlib.reload(evaluate_detection)
evaluate_detection.save_best_checkpoint(project_path)
# Out:
# Saved best-performing checkpoint for model "black_top."

# %%
performance = evaluate_detection.run_test(project_path)
# Out:
# detecting using black_top
# /home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator/detection/black_top_model
# is now:/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator/detection/black_top_model/model.ckpt-92859
# INFO:tensorflow:Restoring parameters from /home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator/detection/black_top_model/model.ckpt-92859
# Found model for global step: 92859

# %%
from multibox_detection import evaluate_detection
import importlib
importlib.reload(evaluate_detection)
project_path = '/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator'
frame_num = 15
evaluate_detection.plot_frame(project_path, frame_num, markersize=7, figsize=[10,10], confidence_thr=0.75)
# Out:
# Sample frame for black_top detector:
# ['/home/cristina/Desktop/ericykma/annotation_budget_projects/15000_frames_1_annotator/annotation_data/test_sets/black_top_detection/test0000015_image0014734_MARS_top_14734.jpg']
# 1234

# %% [markdown]
# ### 3.3 Evaluate model performance on a held-out test set
#
# After picking the checkpoint that performs best on your validation set, we can evaluate that model's performance on the test set:
#
#
# First, we'll run our selected model on the test set. `run_test` takes optional arguments:
# * `detector_names`, the subset of models to evaluate (defaults to all.)
# * `num_images`, the number of images in the test set to evaluate on (defaults to all.)
#
# It also returns an object `performance` that we can use to generate some figures.

# %% [markdown]
# First, let's look at ground truth and predicted bounding boxes for a sample frame. The `Multibox Detection` model makes multiple object detection predictions, each with an associated confidence value.
#
# MARS keeps only the box with the highest confidence score, however when plotting we also show all predicted bounding boxes with a confidence of 0.75 or higher. To change this threshold, modify the optional `confidence_thr` argument to be some value between 0 (lowest) and 1 (highest).

# %%
from multibox_detection import evaluate_detection

project_path = '/home/cristina/Desktop/ericykma/reproduce'
frame_num = 5

evaluate_detection.plot_frame(project_path, frame_num, markersize=7, figsize=[10,10], confidence_thr=0.75)

# %% [markdown]
# Now let's get some summary statistics using the COCO API. The most common metric for evaluating detector performance is the **Intesection over Union (IoU)** - the ratio of the area of overlap between ground truth and predicted boxes, divided by the union of their areas- ie $(\textrm{ground truth} \cap \textrm{predicted})/(\textrm{ground truth} \cup \textrm{predicted})$.
#
# We'll report the **mean Average Precision** and **mean Average Recall** (mAP and mAR) of the IoU, which are the average of Precision and Recall values computed over a range of thresholds on IoU values. This is a standard method for evaluating object detector performance; see the MARS manuscript for an explanation of this metric, or [this article](https://medium.com/@timothycarlen/understanding-the-map-evaluation-metric-for-object-detection-a07fe6962cf3) for further reading.

# %%
performance = evaluate_detection.coco_eval(project_path)

for model in performance.keys():
    print('Performance for ' + model + ':')
    performance[model].summarize()

# %% [markdown]
# Finally, we'll plot **PR Curves**, showing the Precision vs Recall of our detector for various confidence thresholds. Line color here indicates the minimum IoU required to be counted as a correct detection.

# %%
from multibox_detection import evaluate_detection

project_path = '/home/cristina/Desktop/ericykma/reproduce'
evaluate_detection.pr_curve(project_path)
