# %%
import create_new_project
import importlib
importlib.reload(create_new_project)
from create_new_project import *

location = '/home/cristina/Desktop/ericykma/m_dev_fork/'
name = 'test_project'

create_new_project(location, name,
                   download_MARS_checkpoints=True,
                   download_demo_data=True)
# Out:
#   Downloading the 2000-frame sample pose dataset (2000 manually annotated images, 275Mb)...
# Downloading...
# From: https://drive.google.com/uc?id=1DGUmuWgiQXM7Kx6x-QHJQathVIjQOmMR
# To: /home/cristina/Desktop/ericykma/m_dev_fork/test_project/CRIM13_sample_data.zip
# 289MB [00:25, 11.4MB/s]
#   unzipping...
#   sample dataset has been downloaded.
#   Downloading the pre-trained MARS models (2.24Gb)...
# Downloading...
# From: https://drive.google.com/uc?id=1NyAuwI6iQdMgRB2w4zX44yFAgEkux4op
# To: /home/cristina/Desktop/ericykma/m_dev_fork/test_project/MARS_v1_8_models.zip
# 2.41GB [03:32, 11.3MB/s]
#   unzipping...
#   models have been downloaded.
# Project test_project created successfully.

# %%
import pose_annotation_tools.annotation_postprocessing
import importlib
importlib.reload(pose_annotation_tools.annotation_postprocessing)
from pose_annotation_tools.annotation_postprocessing import *

project_path = '/home/cristina/Desktop/ericykma/m_dev_fork/test_project'
annotation_postprocessing(project_path)
# Out:
# WARNING:tensorflow:From /home/cristina/anaconda3/envs/mars_dev/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Hello world
# START MANIFEST_TO_DICT
# CONFIG FILE OPENED
# CONFIG FILE PROCESSED
# OPENING MANIFEST FILE
# Line 0
# Line 1000
# PROCESSED MANIFEST FILE
# FINAL CHECKPOINT BEFORE LOOP
# Processing manifest file...
# 2000
#  line 0
#  line 500
#  line 1000
#   frame 1000
#  line 1500
# Ground-truth keypoint locations extracted!
# Finished making .json
# Generating black_top detection training files...
# <class 'list'>
# <class 'dict'>
# {'class': {'label': 0, 'text': ''},
#  'filename': '/home/cristina/Desktop/ericykma/m_dev_fork/test_project/annotation_data/raw_images/020609_A25_Block5_BCfe1_t_10172.png',
#  'height': 480,
#  'id': '000000',
#  'object': {'area': [13366.080000000005],
#             'bbox': {'count': 1,
#                      'label': [0],
#                      'xmax': [0.19625],
#                      'xmin': [0.025625000000000002],
#                      'ymax': [0.8462500000000001],
#                      'ymin': [0.5912499999999999]}},
#  'width': 640}
# done.
# Generating top pose training files...
# done.
# Generating black_top priors...
# /home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_tfrecords_detection/train_dataset-*
# yeet
# ['/home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_tfrecords_detection/train_dataset-00000-of-00002', '/home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_tfrecords_detection/train_dataset-00001-of-00002']
# done.

# %%
from multibox_detection import train_detect
import importlib
importlib.reload(train_detect)

project_path = '/home/cristina/Desktop/ericykma/m_dev_fork/test_project'
train_detect.run_training(project_path, max_training_steps=1)
# Out:
# /home/cristina/Desktop/ericykma/m_dev_fork/MARS_Developer/multibox_detection/train_detect.py:402: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   bbox_priors = np.array(bbox_priors).astype(np.float32)
# 100
# b
# /home/cristina/Desktop/ericykma/m_dev_fork/test_project/downloaded_models/detection_mouse_top_black/model.ckpt-287889
# /home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_log
# /home/cristina/Desktop/ericykma/m_dev_fork/test_project/downloaded_models/detection_mouse_top_black/model.ckpt-287889
# INFO:tensorflow:Fine-tuning from /home/cristina/Desktop/ericykma/m_dev_fork/test_project/downloaded_models/detection_mouse_top_black/model.ckpt-287889
# INFO:tensorflow:Restoring parameters from /home/cristina/Desktop/ericykma/m_dev_fork/test_project/downloaded_models/detection_mouse_top_black/model.ckpt-287889
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Starting Session.
# INFO:tensorflow:Saving checkpoint to path /home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_log/model.ckpt
# INFO:tensorflow:Starting Queues.
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Recording summary at step 0.
# INFO:tensorflow:Stopping Training.
# INFO:tensorflow:Finished training! Saving model to disk.
# /home/cristina/anaconda3/envs/mars_dev/lib/python3.7/site-packages/tensorflow_core/python/summary/writer/writer.py:386: UserWarning: Attempting to use a closed FileWriter. The operation will be a noop unless the FileWriter is explicitly reopened.
#   warnings.warn("Attempting to use a closed FileWriter. "

# %%
from multibox_detection import evaluate_detection
import importlib
importlib.reload(evaluate_detection)

project_path = '/home/cristina/Desktop/ericykma/m_dev_fork/test_project'
evaluate_detection.plot_training_progress(project_path, omitFirst=0, logTime=False)
evaluate_detection.save_best_checkpoint(project_path)
# Out:
# Saved best-performing checkpoint for model "black_top."

# %%
from multibox_detection import evaluate_detection

project_path = '/home/cristina/Desktop/ericykma/m_dev_fork/test_project'
performance = evaluate_detection.run_test(project_path)
# Out:
# detecting using black_top
# /home/cristina/Desktop/ericykma/m_dev_fork/MARS_Developer/multibox_detection/evaluate_detection.py:545: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   bbox_priors = np.array(bbox_priors).astype(np.float32)
# /home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_model
# is now:/home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_model/model.ckpt-0
# INFO:tensorflow:Restoring parameters from /home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_model/model.ckpt-0
# Found model for global step: 0

# %%
from multibox_detection import evaluate_detection
import importlib
importlib.reload(evaluate_detection)
project_path = '/home/cristina/Desktop/ericykma/m_dev_fork/test_project'
frame_num = 10

evaluate_detection.plot_frame(project_path, frame_num, markersize=7, figsize=[10,10], confidence_thr=0.2)
# Out:
# Sample frame for black_top detector:
# restoring 200 files from ['/home/cristina/Desktop/ericykma/m_dev_fork/test_project/detection/black_top_tfrecords_detection/test_dataset-00000-of-00001']
# [{'image_id': 10, 'bbox': [0.2153691053390503, 0.777999997138977, 0.29738056659698486, 0.1909492015838623], 'score': 0.9972079396247864, 'category_id': 1}, {'image_id': 10, 'bbox': [0.28120800852775574, 0.5363751649856567, 0.20477250218391418, 0.46362483501434326], 'score': 0.001028686761856079, 'category_id': 1}, {'image_id': 10, 'bbox': [0.31383222341537476, 0.6322629451751709, 0.4576503038406372, 0.35899752378463745], 'score': 0.0009509027004241943, 'category_id': 1}, {'image_id': 10, 'bbox': [0.40963250398635864, 0.5867694020271301, 0.27464228868484497, 0.37701719999313354], 'score': 0.0009132027626037598, 'category_id': 1}, {'image_id': 10, 'bbox': [0.11786720156669617, 0.7094719409942627, 0.28293272852897644, 0.2024092674255371], 'score': 0.0009008049964904785, 'category_id': 1}, {'image_id': 10, 'bbox': [0.1247585117816925, 0.7388917803764343, 0.31891515851020813, 0.2611082196235657], 'score': 0.0008994042873382568, 'category_id': 1}, {'image_id': 10, 'bbox': [0.22571171820163727, 0.6709058880805969, 0.3066236227750778, 0.3290941119194031], 'score': 0.0008918046951293945, 'category_id': 1}, {'image_id': 10, 'bbox': [0.4024827480316162, 0.7238439321517944, 0.2797778844833374, 0.27615606784820557], 'score': 0.0008898377418518066, 'category_id': 1}, {'image_id': 10, 'bbox': [0.2128327339887619, 0.7708384990692139, 0.38609708845615387, 0.22916150093078613], 'score': 0.0008645355701446533, 'category_id': 1}, {'image_id': 10, 'bbox': [0.3429945707321167, 0.8525498509407043, 0.23814046382904053, 0.14745014905929565], 'score': 0.0008537769317626953, 'category_id': 1}, {'image_id': 10, 'bbox': [0.3880371153354645, 0.7902331948280334, 0.16430750489234924, 0.05010336637496948], 'score': 0.0008174777030944824, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 0.021618694067001343, 1.0], 'score': 1.1712312698364258e-05, 'category_id': 1}, {'image_id': 10, 'bbox': [1.0, 1.0, 0.0, -0.20248281955718994], 'score': 1.1116266250610352e-05, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 1.0, 0.0], 'score': 1.0639429092407227e-05, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.2823707163333893, 0.5626102685928345, -0.2823707163333893], 'score': 1.0251998901367188e-05, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 0.0, 0.35735654830932617], 'score': 1.0102987289428711e-05, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 1.0, 1.0], 'score': 9.834766387939453e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 0.07370385527610779, 1.0], 'score': 9.745359420776367e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 1.0, 0.8361302614212036], 'score': 9.655952453613281e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.9232891798019409, 1.0, -0.9232891798019409, 0.0], 'score': 9.566545486450195e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [1.0, 1.0, -1.0, 0.0], 'score': 8.910894393920898e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 1.0, 0.0], 'score': 8.821487426757812e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 0.0, 1.0], 'score': 8.821487426757812e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [1.0, 1.0, 0.0, -0.16485220193862915], 'score': 8.612871170043945e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 1.0, 1.0], 'score': 8.493661880493164e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 0.0, 0.24846822023391724], 'score': 8.195638656616211e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 1.0, 0.5966465473175049], 'score': 8.195638656616211e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 0.2732526659965515, 1.0], 'score': 7.957220077514648e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.16492265462875366, 0.10154911875724792, 0.3914613723754883, -0.10154911875724792], 'score': 7.957220077514648e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.9247784614562988, 0.0, -0.03169560432434082, 1.0], 'score': 7.957220077514648e-06, 'category_id': 1}, {'image_id': 10, 'bbox': [0.0, 0.0, 0.0, 1.0], 'score': 7.122 ...
# [{'id': 11, 'image_id': 10, 'category_id': 1, 'area': 18571.48046875, 'bbox': [0.22875000536441803, 0.7516666650772095, 0.27531246840953827, 0.21958333253860474], 'iscrowd': 0}]

# %%
performance = evaluate_detection.coco_eval(project_path)

for model in performance.keys():
    print('Performance for ' + model + ':')
    performance[model].summarize()
# Out:
# Performance for black_top:
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332

# %%
from multibox_detection import evaluate_detection

project_path = '/home/cristina/Desktop/ericykma/m_dev_fork/test_project'
evaluate_detection.pr_curve(project_path)

# %% [markdown]
# I only trained it for one iteration, and based on performance the model supposedly chose the model after 0 training iterations, unless I'm interpreting the plot wrong. These PR curves don't match the PR curves from the provided example notebook, and I'm not really sure why. (Is it because the PR curves are from the original training/test set that the model was tuned on and the CRIM13 stuff is different? If so, that's not clear to me.)
#
# I didn't run any of the pose estimation stuff here because I haven't gotten it to work yet.
